# %%
import csv
import math
from typing import Dict

import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot 
import optuna

from sklearn import *

# %%
train_data = pd.read_csv("data/train.csv")
test_data = pd.read_csv("data/test.csv")

target_labels = ["Оператор", "Есть ли Интернет", "Состав ДХ"]

y = train_data.loc[:, target_labels]
X = train_data.drop(target_labels, axis=1)

index_of_test_data_beginning = len(X.index)
X = pd.concat([X, test_data], ignore_index=True)

X
# Out:
#         id  hhid  Общее телесмотрение  Телесмотрение ночью  \
# 0        0  3348                  647                  437
# 1        1  4182                 2657                  538
# 2        2  1233                 1385                    0
# 3        3  4813                 2861                  607
# 4        4  1782                  478                  174
# ...    ...   ...                  ...                  ...
# 4050  4050   565                 3440                  431
# 4051  4051  4747                  914                    7
# 4052  4052  4400                 1331                    1
# 4053  4053  3089                 2748                  788
# 4054  4054  5184                 5518                  975
#
#       Телесмотрение утром  Телесмотрение в рабочее время  \
# 0                    15.0                             12
# 1                   363.0                           1582
# 2                    49.0                           1134
# 3                   857.0                           1374
# 4                    44.0                             53
# ...                   ...                            ...
# 4050                300.0                           1750
# 4051                 20.0                            865
# 4052                  0.0                            526
# 4053                440.0                           1260
# 4054                352.0                           2672
#
#       Телесмотрение в вечернее время  Телесмотрение в прайм тайм  \
# 0                                120                          63
# 1                                174                           0
# 2                                202                           0
# 3                                 23                           0
# 4                                 79                         128
# ...                              ...                         ...
# 4050                             463                         496
# 4051                              22                           0
# 4052                             474                         330
# 4053                             189                          71
# 4054                             612                         907
#
#       Общее телесмотрение Пн-Пт  Телесмотрение ночью Пн-Пт  ...  \
# 0                         195.0                          0  ...
# 1                         415.0                        133  ...
# 2                         729.0                          0  ...
# 3                        1249.0                        294  ...
# 4                         260.0                          0  ...
# ...                         ...                        ...  ...
# 4050                     1604.0                        118  ...
# 4051                      400.0                          0  ...
# 4052                      754.0                          1  ...
# 4053                      491.0                        164  ...
# 4054                     2118.0                        355  ...
#
#       Просмотр жанра спорт в праздники  Просмотр жанра музыка в рабочее время  \
# 0                                    0                                      0
# 1                                    0                                      0
# 2                                   16                                      0
# 3                                    0                                      0
# 4                                    0                                      0
# ...                                ...                                    ...
# 4050                                 0                                      0
# 4051                                 0                                      0
# 4052                                 0                                      0
# 4053                                 9                                      0
# 4054                                 0                                      0
#
#       Просмотр жанра музыка в праздники  \
# 0                                     0
# 1                                     0
# 2                                     0
# 3                                     0
# 4                                     0
# ...                                 ...
# 4050                                  0
# 4051                                  0
# 4052                                  0
# 4053                                  0
# 4054                                  0
#
#       Просмотр жанра образования в рабочее время  \
# 0                                              0
# 1                                              1
# 2                                              0
# 3                                             11
# 4                                              0
# ...                                          ...
# 4050                                           0
# 4051                                           0
# 4052                                           0
# 4053                                           4
# 4054                                         104
#
#       Просмотр жанра образование в праздники  Размер ДХ  \
# 0                                          1        4.0
# 1                                        109        4.0
# 2                                          0        2.0
# 3                                         11        2.0
# 4                                          0        4.0
# ...                                      ...        ...
# 4050                                       1        3.0
# 4051                                       0        2.0
# 4052                                       0        4.0
# 4053                                     178        2.0
# 4054                                     156        2.0
#
#                    Тип ресивера                                 ФО  \
# 0     Ресивер с поддержкой HDTV  Северо-Западный федеральный округ
# 1     Ресивер с поддержкой HEVC        Уральский федеральный округ
# 2     Ресивер с поддержкой HDTV            Южный федеральный округ
# 3     Ресивер с поддержкой HEVC      Приволжский федеральный округ
# 4     Ресивер с поддержкой HDTV  Северо-Западный федеральный округ
# ...                         ...                                ...
# 4050  Ресивер с поддержкой HDTV      Центральный федеральный округ
# 4051  Ресивер с поддержкой HEVC      Центральный федеральный округ
# 4052  Ресивер с поддержкой HDTV            Южный федеральный округ
# 4053  Ресивер с поддержкой HEVC        Сибирский федеральный округ
# 4054  Ресивер с поддержкой HEVC      Центральный федеральный округ
#
#                                    Тип нас.пункта  Почтовый индекс
# 0     Город с численностью от 45 тыс. до 400 тыс.           182180
# 1              Город с численностью менее 45 тыс.           457024
# 2                            Город более 400 тыс.           350901
# 3                       Сельский населенный пункт           452774
# 4                       Сельский населенный пункт           168068
# ...                                           ...              ...
# 4050                         Город более 400 тыс.           153008
# 4051                    Сельский населенный пункт           309740
# 4052                         Город более 400 тыс.           350088
# 4053                         Город более 400 тыс.           656012
# 4054                    Сельский населенный пункт           171930
#
# [4055 rows x 41 columns]

# %%
X.drop(["id", "hhid"], axis=1, inplace=True)

# %%
X.isna().sum()
# Out:
# Общее телесмотрение                            0
# Телесмотрение ночью                            0
# Телесмотрение утром                           25
# Телесмотрение в рабочее время                  0
# Телесмотрение в вечернее время                 0
# Телесмотрение в прайм тайм                     0
# Общее телесмотрение Пн-Пт                     25
# Телесмотрение ночью Пн-Пт                      0
# Телесмотрение утром Пн-Пт                      0
# Телесмотрение в рабочее время Пн-Пт            0
# Телесмотрение в вечернее время Пн-Пт           0
# Телесмотрение в прайм тайм Пн-Пт               0
# Общее телесмотрение в выходные                 0
# Телесмотрение ночью в выходные                 0
# Телесмотрение утром в выходные                 0
# Телесмотрение в рабочее время в выходные       0
# Телесмотрение вечером в выходные               0
# Телесмотрение в прайм тайм в выходные          0
# Просмотр жанра кино в рабочее время            0
# Просмотр жанра кино в праздники                0
# Просмотр жанра приключения в рабочее время     0
# Просмотр жанра приключение в праздники         0
# Просмотра жанра сад в рабочее время            0
# Просмотр жанра сад в праздники                 0
# Просмотра жанра комедия в рабочее время        0
# Просмотр жанра комедия в праздники             0
# Просмотр жанра хоби в рабочее время            0
# Просмотр жанра хобби в праздники               0
# Просмотр жанра спорт в рабочее время           0
# Просмотр жанра спорт в праздники               0
# Просмотр жанра музыка в рабочее время          0
# Просмотр жанра музыка в праздники              0
# Просмотр жанра образования в рабочее время     0
# Просмотр жанра образование в праздники         0
# Размер ДХ                                     25
# Тип ресивера                                   0
# ФО                                             0
# Тип нас.пункта                                25
# Почтовый индекс                                0
# dtype: int64

# %%
col_names_for_tv_viewing = ["Телесмотрение утром", "Телесмотрение ночью", "Телесмотрение в рабочее время", "Телесмотрение в вечернее время", "Телесмотрение в прайм тайм", "Общее телесмотрение"]

indexes_of_rows_with_missed_values_for_morning_tv_viewing = X[col_names_for_tv_viewing[0]].isnull().where(lambda x: x).dropna().index

tv_viewing_per_part_of_day_and_in_total = X.loc[indexes_of_rows_with_missed_values_for_morning_tv_viewing, col_names_for_tv_viewing[1:]]

tv_viewing_in_total = tv_viewing_per_part_of_day_and_in_total[col_names_for_tv_viewing[-1]]
tv_viewing_per_part_of_day_and_in_total.drop(col_names_for_tv_viewing[-1], axis=1, inplace=True)

morning_tv_viewing_data = []
for index, row in tv_viewing_per_part_of_day_and_in_total.iterrows():
    morning_tv_viewing = tv_viewing_in_total[index] - sum(row)
    morning_tv_viewing_data.append(morning_tv_viewing)
morning_tv_viewings = pd.Series(data=morning_tv_viewing_data, index=tv_viewing_per_part_of_day_and_in_total.index)

X.loc[morning_tv_viewings.index, col_names_for_tv_viewing[0]] = morning_tv_viewings

X.loc[morning_tv_viewings.index, :]
# Out:
#       Общее телесмотрение  Телесмотрение ночью  Телесмотрение утром  \
# 987                   578                  123                 42.0
# 988                   504                    0                131.0
# 989                   409                  110                  0.0
# 990                  1517                    0                146.0
# 991                    49                    0                  0.0
# 992                  1047                   77                160.0
# 993                   227                    0                 16.0
# 994                  1690                    3                123.0
# 995                   411                    0                134.0
# 996                  2164                  431                265.0
# 997                  3068                  266                541.0
# 998                  1935                  182                261.0
# 999                  1358                  169                211.0
# 1000                 1935                  151                207.0
# 1001                  264                  106                  0.0
# 1002                 1265                   18                441.0
# 1003                 3156                  113                550.0
# 1004                 1575                    0                  0.0
# 1005                 1855                  440                480.0
# 1006                 1874                    0                233.0
# 1007                 1157                    0                127.0
# 1008                  701                    9                183.0
# 1009                  686                  175                194.0
# 1010                  847                   43                126.0
# 1011                 1380                  143                219.0
#
#       Телесмотрение в рабочее время  Телесмотрение в вечернее время  \
# 987                             336                              77
# 988                             225                             121
# 989                             282                              17
# 990                            1202                             156
# 991                              49                               0
# 992                             507                             123
# 993                             211                               0
# 994                             905                             425
# 995                             248                              29
# 996                            1083                             199
# 997                            1834                             305
# 998                            1246                             206
# 999                             978                               0
# 1000                           1117                             221
# 1001                            158                               0
# 1002                            712                              94
# 1003                           1888                             267
# 1004                            709                             484
# 1005                            935                               0
# 1006                           1470                             149
# 1007                            915                             115
# 1008                            508                               1
# 1009                            317                               0
# 1010                            581                              97
# 1011                           1010                               8
#
#       Телесмотрение в прайм тайм  Общее телесмотрение Пн-Пт  \
# 987                            0                      429.0
# 988                           27                      308.0
# 989                            0                      408.0
# 990                           13                      617.0
# 991                            0                        0.0
# 992                          180                       76.0
# 993                            0                      211.0
# 994                          234                      704.0
# 995                            0                      159.0
# 996                          186                      819.0
# 997                          122                     1377.0
# 998                           40                     1324.0
# 999                            0                      630.0
# 1000                         239                        NaN
# 1001                           0                        NaN
# 1002                           0                        NaN
# 1003                         338                        NaN
# 1004                         382                        NaN
# 1005                           0                        NaN
# 1006                          22                        NaN
# 1007                           0                        NaN
# 1008                           0                        NaN
# 1009                           0                        NaN
# 1010                           0                        NaN
# 1011                           0                        NaN
#
#       Телесмотрение ночью Пн-Пт  Телесмотрение утром Пн-Пт  \
# 987                           0                         17
# 988                           0                          0
# 989                         109                          0
# 990                           0                        118
# 991                           0                          0
# 992                          76                          0
# 993                           0                          0
# 994                           2                         53
# 995                           0                        129
# 996                         111                        155
# 997                          67                        361
# 998                           0                        261
# 999                         109                        131
# 1000                          4                          0
# 1001                         16                          0
# 1002                          0                          0
# 1003                         60                        185
# 1004                          0                          0
# 1005                         76                         51
# 1006                          0                        233
# 1007                          0                        127
# 1008                          9                        183
# 1009                        175                        186
# 1010                          0                          0
# 1011                        143                        181
#
#       Телесмотрение в рабочее время Пн-Пт  ...  \
# 987                                   335  ...
# 988                                   160  ...
# 989                                   282  ...
# 990                                   499  ...
# 991                                     0  ...
# 992                                     0  ...
# 993                                   211  ...
# 994                                   300  ...
# 995                                    30  ...
# 996                                   218  ...
# 997                                   777  ...
# 998                                   897  ...
# 999                                   390  ...
# 1000                                   79  ...
# 1001                                   24  ...
# 1002                                    0  ...
# 1003                                  881  ...
# 1004                                  372  ...
# 1005                                  145  ...
# 1006                                  847  ...
# 1007                                  379  ...
# 1008                                  431  ...
# 1009                                  299  ...
# 1010                                    0  ...
# 1011                                  352  ...
#
#       Просмотр жанра спорт в праздники  Просмотр жанра музыка в рабочее время  \
# 987                                  0                                      1
# 988                                 24                                      0
# 989                                  0                                      0
# 990                                  0                                    105
# 991                                  0                                      0
# 992                                  0                                      0
# 993                                  0                                      0
# 994                                 10                                      0
# 995                                  0                                      0
# 996                                  0                                      0
# 997                                  1                                    165
# 998                                  0                                     14
# 999                                  0                                      0
# 1000                                 0                                      0
# 1001                                 0                                      0
# 1002                                 0                                      0
# 1003                                 0                                      0
# 1004                                 0                                      0
# 1005                                 0                                      0
# 1006                                 0                                      0
# 1007                                 0                                      0
# 1008                                 0                                      0
# 1009                                 0                                      0
# 1010                                 0                                      0
# 1011                                 0                                      0
#
#       Просмотр жанра музыка в праздники  \
# 987                                   0
# 988                                   0
# 989                                   0
# 990                                  26
# 991                                   0
# 992                                   0
# 993                                   0
# 994                                   0
# 995                                   0
# 996                                   0
# 997                                   0
# 998                                   0
# 999                                   0
# 1000                                  0
# 1001                                  0
# 1002                                  0
# 1003                                  0
# 1004                                  0
# 1005                                  0
# 1006                                  0
# 1007                                  0
# 1008                                  0
# 1009                                  0
# 1010                                  0
# 1011                                  0
#
#       Просмотр жанра образования в рабочее время  \
# 987                                            0
# 988                                            0
# 989                                            3
# 990                                            0
# 991                                            0
# 992                                            0
# 993                                            0
# 994                                            0
# 995                                            0
# 996                                            1
# 997                                            0
# 998                                            0
# 999                                           61
# 1000                                           0
# 1001                                           0
# 1002                                           0
# 1003                                           0
# 1004                                           0
# 1005                                           0
# 1006                                           0
# 1007                                           0
# 1008                                           0
# 1009                                           0
# 1010                                           0
# 1011                                           0
#
#       Просмотр жанра образование в праздники  Размер ДХ  \
# 987                                        0        3.0
# 988                                        0        2.0
# 989                                        0        2.0
# 990                                        0        4.0
# 991                                        0        2.0
# 992                                        0        3.0
# 993                                        0        2.0
# 994                                        0        1.0
# 995                                        0        4.0
# 996                                        0        2.0
# 997                                        0        4.0
# 998                                        0        2.0
# 999                                       57        3.0
# 1000                                       0        2.0
# 1001                                       0        3.0
# 1002                                       0        6.0
# 1003                                      22        3.0
# 1004                                       0        3.0
# 1005                                       0        4.0
col_names_for_tv_viewing_in_work_days = ["Общее телесмотрение Пн-Пт", "Телесмотрение утром Пн-Пт", "Телесмотрение ночью Пн-Пт", "Телесмотрение в рабочее время Пн-Пт", "Телесмотрение в вечернее время Пн-Пт", "Телесмотрение в прайм тайм Пн-Пт"]

indexes_of_rows_with_missed_values_for_tv_viewing_in_total = X[col_names_for_tv_viewing_in_work_days[0]].isnull().where(lambda x: x).dropna().index

tv_viewing_per_part_of_day = X.loc[indexes_of_rows_with_missed_values_for_tv_viewing_in_total, col_names_for_tv_viewing_in_work_days[1:]]

tv_viewing_in_total_data = []
for index, row in tv_viewing_per_part_of_day.iterrows():
    tv_viewing_in_total = sum(row)
    tv_viewing_in_total_data.append(tv_viewing_in_total)
tv_viewings_in_total = pd.Series(data=tv_viewing_in_total_data, index=tv_viewing_per_part_of_day.index)

X.loc[tv_viewings_in_total.index, col_names_for_tv_viewing_in_work_days[0]] = tv_viewings_in_total

X.loc[tv_viewings_in_total.index, :]
# Out:
#       Общее телесмотрение  Телесмотрение ночью  Телесмотрение утром  \
# 1000                 1935                  151                207.0
# 1001                  264                  106                  0.0
# 1002                 1265                   18                441.0
# 1003                 3156                  113                550.0
# 1004                 1575                    0                  0.0
# 1005                 1855                  440                480.0
# 1006                 1874                    0                233.0
# 1007                 1157                    0                127.0
# 1008                  701                    9                183.0
# 1009                  686                  175                194.0
# 1010                  847                   43                126.0
# 1011                 1380                  143                219.0
# 1012                   92                    0                  0.0
# 1013                   47                    9                 36.0
# 1014                  625                    0                105.0
# 1015                  105                    0                  0.0
# 1016                 2006                   49                321.0
# 1017                  119                   28                  0.0
# 1018                  384                    1                  5.0
# 1019                 1466                   92                134.0
# 1020                 1051                   88                434.0
# 1021                  881                    0                 42.0
# 1022                 1188                    0                 98.0
# 1023                 2349                  113                415.0
# 1024                  455                    0                 34.0
#
#       Телесмотрение в рабочее время  Телесмотрение в вечернее время  \
# 1000                           1117                             221
# 1001                            158                               0
# 1002                            712                              94
# 1003                           1888                             267
# 1004                            709                             484
# 1005                            935                               0
# 1006                           1470                             149
# 1007                            915                             115
# 1008                            508                               1
# 1009                            317                               0
# 1010                            581                              97
# 1011                           1010                               8
# 1012                             53                              39
# 1013                              2                               0
# 1014                            520                               0
# 1015                            105                               0
# 1016                           1128                             346
# 1017                             91                               0
# 1018                             83                             113
# 1019                            905                             243
# 1020                            529                               0
# 1021                            794                              45
# 1022                            686                             246
# 1023                           1660                             138
# 1024                            421                               0
#
#       Телесмотрение в прайм тайм  Общее телесмотрение Пн-Пт  \
# 1000                         239                      304.0
# 1001                           0                       40.0
# 1002                           0                        0.0
# 1003                         338                     1473.0
# 1004                         382                      806.0
# 1005                           0                      272.0
# 1006                          22                     1080.0
# 1007                           0                      506.0
# 1008                           0                      623.0
# 1009                           0                      660.0
# 1010                           0                        0.0
# 1011                           0                      676.0
# 1012                           0                        0.0
# 1013                           0                        0.0
# 1014                           0                      549.0
# 1015                           0                        0.0
# 1016                         162                     1045.0
# 1017                           0                        0.0
# 1018                         182                       42.0
# 1019                          92                      201.0
# 1020                           0                      196.0
# 1021                           0                       42.0
# 1022                         158                      201.0
# 1016                    Сельский населенный пункт           238716
# 1017           Город с численностью менее 45 тыс.           456870
# 1018  Город с численностью от 45 тыс. до 400 тыс.           249030
# 1019           Город с численностью менее 45 тыс.           396901
# 1020                    Сельский населенный пункт           156530
# 1021                         Город более 400 тыс.           400065
# 1022                         Город более 400 тыс.           236005
# 1023                    Сельский населенный пункт           442868
# 1024                    Сельский населенный пункт           347513
#
# [25 rows x 39 columns]

# %%
family = y["Состав ДХ"].apply(lambda x: x.split(" и "))
y.drop("Состав ДХ", axis=1, inplace=True)

elder_generation  = family.transform(lambda x: x[0])
children = family.transform(lambda x: x[1])

y["Члены семьи в возрасте от 55 лет"] = elder_generation
y["Члены семьи до 18 лет"] = children

# %%
encoder_per_label = {
    "Оператор": preprocessing.LabelEncoder(),
    "Есть ли Интернет": preprocessing.LabelEncoder(),
    "Члены семьи в возрасте от 55 лет": preprocessing.LabelEncoder(),
    "Члены семьи до 18 лет": preprocessing.LabelEncoder()
}

for label in encoder_per_label.keys():
    y[label] = encoder_per_label[label].fit_transform(y[label])

predictor_col_names = list(encoder_per_label.keys())

# %%
categorical_encoder = preprocessing.LabelEncoder()

X.loc[:, ["Тип ресивера", "Тип нас.пункта"]] = X.loc[:, ["Тип ресивера", "Тип нас.пункта"]].apply(categorical_encoder.fit_transform)
X["Тип нас.пункта"].where(lambda x: x != 4, other=np.nan, inplace=True)
X["Тип ресивера"] = X["Тип ресивера"].astype(int)

# X.loc[:, ["Тип ресивера", "ФО", "Тип нас.пункта"]]
X.loc[:, ["Тип ресивера", "Тип нас.пункта"]]
# Out:
#       Тип ресивера Тип нас.пункта
# 0                0              2
# 1                1              1
# 2                0              0
# 3                1              3
# 4                0              3
# ...            ...            ...
# 4050             0              0
# 4051             1              3
# 4052             0              0
# 4053             1              0
# 4054             1              3
#
# [4055 rows x 2 columns]

# %%
standard_scaler = preprocessing.StandardScaler()
tv_viewing_data = X.drop(["Размер ДХ", "Тип ресивера", "Тип нас.пункта", "ФО", "Почтовый индекс"], axis=1)

X.loc[:, tv_viewing_data.columns] = standard_scaler.fit_transform(tv_viewing_data)

# %%
scaler = preprocessing.MinMaxScaler()
post_index = X["Почтовый индекс"].to_numpy().reshape(-1, 1)

X["Почтовый индекс"] = scaler.fit_transform(post_index)

X["Почтовый индекс"]
# Out:
# 0       0.029493
# 1       0.073988
# 2       0.056808
# 3       0.073300
# 4       0.027209
#           ...
# 4050    0.024771
# 4051    0.050144
# 4052    0.056676
# 4053    0.106202
# 4054    0.027834
# Name: Почтовый индекс, Length: 4055, dtype: float64

# %%
federal_district_one_hot_encoded = pd.get_dummies(X.loc[:, ["ФО"]]).astype(int)
X = pd.concat([X, federal_district_one_hot_encoded], axis=1)
X.drop(["ФО"], axis=1, inplace=True)

# %%
# n_neighbors = sqrt(number_of_samples)/2
imputer = impute.KNNImputer(n_neighbors=28)

cols_for_household_size_imputation = [*tv_viewing_data.columns, "Размер ДХ"]
data_for_household_size_imputation = X.loc[:, cols_for_household_size_imputation]

indexes_of_rows_with_missing_values_for_household_size= data_for_household_size_imputation.loc[:, "Размер ДХ"].isna().where(lambda x: x).dropna().index
rows_with_missing_values_for_household_size = data_for_household_size_imputation.loc[indexes_of_rows_with_missing_values_for_household_size, :]
#
rows_without_missing_values_for_household_size = data_for_household_size_imputation.loc[X["Размер ДХ"].notna().where(lambda x: x).dropna().index, :]

imputer.fit(rows_without_missing_values_for_household_size)
# 
imputed_data = imputer.transform(rows_with_missing_values_for_household_size)

index_of_household_column = data_for_household_size_imputation.columns.get_loc("Размер ДХ")
for imputed_row  in imputed_data:
    imputed_row[index_of_household_column] = round(imputed_row[index_of_household_column])

X.loc[indexes_of_rows_with_missing_values_for_household_size, cols_for_household_size_imputation] = imputed_data

X.loc[indexes_of_rows_with_missing_values_for_household_size]

# kind_of_inhabited_locality_formatted_for_decoding = X.loc[:, ["Тип нас.пункта"]].to_numpy().reshape(1, -1)[0].astype(int)
# X["Тип нас.пункта"] = categorical_encoder.inverse_transform(kind_of_inhabited_locality_formatted_for_decoding)
# Out:
#       Общее телесмотрение  Телесмотрение ночью  Телесмотрение утром  \
# 2004             1.032353            -0.527804             1.444114
# 2005             2.101516             2.947383             1.933736
# 2006            -0.879289            -0.596790            -0.098657
# 2007            -0.088573            -0.644218            -0.380420
# 2008            -0.695443            -0.644218            -0.934709
# 2009             0.365688            -0.066458             0.224678
# 2010            -1.082770            -0.644218            -0.934709
# 2011             0.705714             2.192845             1.753592
# 2012             1.159974             0.994207            -0.551326
# 2013             0.047973            -0.626972            -0.860804
# 2014            -0.392008            -0.644218            -0.648327
# 2015             0.156853             0.834676            -0.080181
# 2016            -1.064920            -0.644218            -0.934709
# 2017            -1.180047            -0.639907            -0.934709
# 2018            -0.499995            -0.644218            -0.934709
# 2019            -0.781119             0.118943             0.053773
# 2020             0.561136             2.740424             0.086106
# 2021            -0.584779            -0.644218            -0.893138
# 2022            -0.356310            -0.644218            -0.934709
# 2023            -0.475007            -0.644218            -0.288039
# 2024             1.989959             3.404417             1.762830
# 2025            -0.744529            -0.010406             0.815920
# 2026            -0.897139            -0.644218            -0.648327
# 2027            -0.276881             0.627717            -0.015513
# 2028            -0.456265            -0.639907            -0.611374
#
#       Телесмотрение в рабочее время  Телесмотрение в вечернее время  \
# 2004                       0.968233                        1.974052
# 2005                       1.676248                        1.304999
# 2006                      -1.164850                       -0.121472
# 2007                       0.291853                        0.149936
# 2008                      -0.791259                        0.187807
# 2009                       0.742271                       -0.197214
# 2010                      -1.155812                       -0.197214
# 2011                       0.114096                       -0.556987
# 2012                       1.254452                        1.614278
# 2013                       0.569033                       -0.077289
# 2014                      -0.425201                        0.610699
# 2015                       0.278295                       -0.632729
# 2016                      -1.148280                       -0.077289
# 2017                      -1.136228                       -0.834707
# 2018                      -0.318245                       -0.070977
# 2019                      -1.050363                       -0.834707
# 2020                       0.094513                       -0.632729
# 2021                      -0.981068                        1.191386
# 2022                      -0.032026                        0.370850
# 2023                      -0.282091                       -0.304514
# 2024                       1.733492                       -0.449686
# 2025                      -1.191966                       -0.834707
# 2026                      -0.750586                       -0.834707
# [25 rows x 45 columns]

# %%
cols_for_type_of_inhabited_locality_imputation = [*federal_district_one_hot_encoded.columns, "Почтовый индекс", "Тип нас.пункта"]
data_for_type_of_inhabited_locality_imputation = X.loc[:, cols_for_type_of_inhabited_locality_imputation]

indexes_of_rows_with_missing_values_for_type_of_inhabited_locality = data_for_type_of_inhabited_locality_imputation.loc[:, "Тип нас.пункта"].isna().where(lambda x: x).dropna().index

rows_with_missing_values_for_type_of_inhabited_locality = data_for_type_of_inhabited_locality_imputation.loc[indexes_of_rows_with_missing_values_for_type_of_inhabited_locality, :]
#
rows_without_missing_values_for_type_of_inhabited_locality = data_for_type_of_inhabited_locality_imputation.loc[X["Тип нас.пункта"].notna().where(lambda x: x).dropna().index, :]

imputer.fit(rows_without_missing_values_for_type_of_inhabited_locality)
# 
imputed_data = imputer.transform(rows_with_missing_values_for_type_of_inhabited_locality)

index_of_type_of_inhabited_locality_column = data_for_type_of_inhabited_locality_imputation.columns.get_loc("Тип нас.пункта")
for imputed_row  in imputed_data:
    imputed_row[index_of_type_of_inhabited_locality_column] = round(imputed_row[index_of_type_of_inhabited_locality_column])

X.loc[indexes_of_rows_with_missing_values_for_type_of_inhabited_locality, cols_for_type_of_inhabited_locality_imputation] = imputed_data

X.loc[indexes_of_rows_with_missing_values_for_type_of_inhabited_locality]

# kind_of_inhabited_locality_formatted_for_decoding = X.loc[:, ["Тип нас.пункта"]].to_numpy().reshape(1, -1)[0].astype(int)
# X["Тип нас.пункта"] = categorical_encoder.inverse_transform(kind_of_inhabited_locality_formatted_for_decoding)
# Out:
#      Общее телесмотрение  Телесмотрение ночью  Телесмотрение утром  \
# 200             1.367916             0.442316             1.878307
# 201            -0.761485            -0.644218            -0.814613
# 202            -0.002005            -0.359650            -0.214134
# 203            -0.323289             1.429683            -0.089419
# 204            -0.782012            -0.644218            -0.925471
# 205             1.836456             1.214101             0.451013
# 206            -1.187187            -0.644218            -0.934709
# 207             0.366580            -0.501934             0.820539
# 208            -0.468759            -0.644218            -0.371182
# 209             0.021199            -0.644218            -0.348087
# 210             0.234496             4.210695            -0.140228
# 211            -0.893569            -0.639907            -0.934709
# 212             1.381303            -0.639907             0.742015
# 213            -1.127392            -0.523492            -0.934709
# 214             0.751229            -0.527804             1.425638
# 215            -0.466974            -0.644218            -0.676041
# 216            -1.042609            -0.294975            -0.320372
# 217             1.076083             0.519926             0.894444
# 218            -0.901601             0.110320            -0.209515
# 219            -0.862333            -0.583855            -0.819232
# 220            -0.928375            -0.644218            -0.934709
# 221            -0.699013             0.011152            -0.412754
# 222             0.321957            -0.644218            -0.454326
# 223            -0.410750            -0.644218            -0.851566
# 224             0.556673             0.981272             1.407161
#
#      Телесмотрение в рабочее время  Телесмотрение в вечернее время  \
# 200                       0.936599                        1.437547
# 201                      -0.467380                       -0.834707
# 202                       0.519322                       -0.834707
# 203                      -0.688823                       -0.834707
# 204                      -0.465874                       -0.834707
# 205                       1.411119                        2.087664
# 206                      -1.146773                       -0.834707
# 207                       0.853746                       -0.834707
# 208                      -0.117892                       -0.834707
# 209                       0.456052                        0.194119
# 210                      -0.791259                       -0.462310
# 211                      -1.107607                       -0.070977
# 212                       1.719934                        1.620590
# 213                      -1.088023                       -0.834707
# 214                       0.338552                        1.929869
# 215                      -0.423694                        0.875795
# 216                      -1.225107                       -0.834707
# 217                       0.921534                        0.692753
# 218                      -1.166357                       -0.828395
# 219                      -0.711419                       -0.639041
# 220                      -0.726484                       -0.765277
# 221                      -0.821388                       -0.834707
# 222                       1.093266                       -0.203525
# 223                      -0.270040                       -0.045730
# 224                       0.439482                       -0.727406
#
#      Телесмотрение в прайм тайм  Общее телесмотрение Пн-Пт  \
# 200                    1.091069                   0.225760
# 201                   -0.532704                  -1.075389
# 202                   -0.532704                   0.723914
# 203                   -0.532704                  -0.547494
# 204                   -0.532704                  -0.579094
# 205                    2.576916                   1.906101
# 206                   -0.532704                  -1.064236
# 207                   -0.532704                   1.010167
# 208                   -0.532704                   0.513872
# 209                   -0.532704                   0.307547
# 210                   -0.532704                   0.164420
# 211                    0.602057                  -0.367192
# 212                    0.859102                   1.222068
# 213                   -0.532704                  -1.075389
# 214                    0.783869                   0.893064
# 215                   -0.532704                  -0.543777
# 216                   -0.532704                  -0.677609
# 217                    1.065992                   0.530601
# 218                   -0.532704                  -1.002896
# 219                   -0.501357                  -0.653445
# 220                   -0.532704                  -0.856052
# 221                   -0.118924                  -0.493589
# 222                   -0.532704                   0.132821
# 223                    0.376358                  -1.075389
# 224                   -0.532704                   0.339146
#
#      Телесмотрение ночью Пн-Пт  Телесмотрение утром Пн-Пт  \
# 200                   0.704083                   2.444164
# 201                  -0.559718                  -0.815633
# 202                   0.039418                   0.604837
# 203                   0.573023                  -0.815633
# 204                  -0.559718                  -0.797422
# 205                   0.544938                   1.633767
# 206                  -0.559718                  -0.815633
# 207                  -0.381850                   0.841582
# 208                  -0.559718                   0.286142
# 209                  -0.559718                   0.340775
# 210                   2.735527                   0.231508
# 211                  -0.550356                  -0.815633
# 212                  -0.559718                   2.489692
# 213                  -0.559718                  -0.815633
# 214                  -0.559718                   2.170996
# 215                  -0.559718                  -0.815633
# 216                   0.198563                   0.395409
# 217                   0.385793                   0.832477
# 218                  -0.559718                  -0.815633
# 219                  -0.428657                  -0.587993
# 220                  -0.559718                  -0.815633
# 221                  -0.054197                  -0.642627
# 222                  -0.559718                  -0.524254
# 223                  -0.559718                  -0.815633
# 224                   0.245370                   0.859793
#
#      Телесмотрение в рабочее время Пн-Пт  ...  Тип ресивера  Тип нас.пункта  \
# 200                            -0.406561  ...             1             3.0
# 201                            -1.030929  ...             1             3.0
# 202                             1.225240  ...             1             1.0
# 203                            -0.539277  ...             0             2.0
# 204                            -0.231617  ...             1             2.0
# 205                             2.142186  ...             0             1.0
# 206                            -1.012831  ...             0             3.0
# 207                             1.747055  ...             1             3.0
# 208                             1.183013  ...             1             3.0
# 209                             0.609921  ...             1             1.0
# 210                            -0.427675  ...             1             2.0
# 211                            -0.795660  ...             1             3.0
# 212                             1.469558  ...             1             1.0
# 213                            -1.030929  ...             1             2.0
# 214                           0
# 215                           0
# 216                           0
# 217                           0
# 218                           0
# 219                           0
# 220                           1
# 221                           0
# 222                           0
# 223                           0
# 224                           0
#
# [25 rows x 45 columns]

# %%
# kind_of_inhabited_locality = [
#     [
#         "Сельский населенный пункт",
#         "Город с численностью менее 45 тыс.",
#         "Город с численностью от 45 тыс. до 400 тыс.",
#         "Город более 400 тыс."
#     ]
# ]
# print(kind_of_inhabited_locality.reshape(-1 , 1))

# ordinal_encoder = preprocessing.OneHotEncoder(
#     # categories=kind_of_inhabited_locality
# )
kind_of_inhabited_locality_one_hot_encoded = pd.get_dummies(X.loc[:, ["Тип нас.пункта"]]).astype(int)
print(kind_of_inhabited_locality_one_hot_encoded)
X = pd.concat([X, kind_of_inhabited_locality_one_hot_encoded], axis=1)
X.drop(["Тип нас.пункта"], axis=1, inplace=True)

# print(ordinal_encoder.fit_transform().toarray())

# print(ordinal_encoder.categories_)
# Out:
#       Тип нас.пункта_0  Тип нас.пункта_1  Тип нас.пункта_2  Тип нас.пункта_3
# 0                    0                 0                 1                 0
# 1                    0                 1                 0                 0
# 2                    1                 0                 0                 0
# 3                    0                 0                 0                 1
# 4                    0                 0                 0                 1
# ...                ...               ...               ...               ...
# 4050                 1                 0                 0                 0
# 4051                 0                 0                 0                 1
# 4052                 1                 0                 0                 0
# 4053                 1                 0                 0                 0
# 4054                 0                 0                 0                 1
#
# [4055 rows x 4 columns]

# %%
X.drop([*federal_district_one_hot_encoded.columns, "Почтовый индекс"], axis=1, inplace=True)

# %%
pyplot.subplots(figsize=(10, 10))

sns.heatmap(X.drop(kind_of_inhabited_locality_one_hot_encoded, axis=1).corr(), xticklabels=1, yticklabels=1)
# Out:
# <Axes: >

# %%
# print(y.loc[:, "Оператор"].shape)
# print(X.drop(kind_of_inhabited_locality_one_hot_encoded, axis=1).shape)
print(X.drop(kind_of_inhabited_locality_one_hot_encoded, axis=1).corrwith(y["Оператор"]))
sns.heatmap(np.asarray(X.drop(kind_of_inhabited_locality_one_hot_encoded, axis=1).corrwith(y["Оператор"])).reshape(-1, 1), xticklabels=1, yticklabels=1)
# Out:
# Общее телесмотрение                           0.074005
# Телесмотрение ночью                           0.010242
# Телесмотрение утром                           0.040870
# Телесмотрение в рабочее время                 0.077599
# Телесмотрение в вечернее время                0.063857
# Телесмотрение в прайм тайм                    0.061823
# Общее телесмотрение Пн-Пт                     0.087728
# Телесмотрение ночью Пн-Пт                     0.043484
# Телесмотрение утром Пн-Пт                     0.064629
# Телесмотрение в рабочее время Пн-Пт           0.085158
# Телесмотрение в вечернее время Пн-Пт          0.042044
# Телесмотрение в прайм тайм Пн-Пт              0.053291
# Общее телесмотрение в выходные                0.050377
# Телесмотрение ночью в выходные               -0.014619
# Телесмотрение утром в выходные                0.011613
# Телесмотрение в рабочее время в выходные      0.054887
# Телесмотрение вечером в выходные              0.068041
# Телесмотрение в прайм тайм в выходные         0.056327
# Просмотр жанра кино в рабочее время           0.037439
# Просмотр жанра кино в праздники               0.006841
# Просмотр жанра приключения в рабочее время    0.018522
# Просмотр жанра приключение в праздники        0.033027
# Просмотра жанра сад в рабочее время           0.043111
# Просмотр жанра сад в праздники                0.061495
# Просмотра жанра комедия в рабочее время       0.047259
# Просмотр жанра комедия в праздники           -0.040388
# Просмотр жанра хоби в рабочее время           0.026368
# Просмотр жанра хобби в праздники             -0.059412
# Просмотр жанра спорт в рабочее время          0.031988
# Просмотр жанра спорт в праздники              0.022704
# Просмотр жанра музыка в рабочее время         0.013230
# Просмотр жанра музыка в праздники            -0.006244
# Просмотр жанра образования в рабочее время   -0.008949
# Просмотр жанра образование в праздники       -0.013910
# Размер ДХ                                    -0.010475
# Тип ресивера                                 -0.012353
# dtype: float64
# <Axes: >

# %%
X_final_test = X.iloc[index_of_test_data_beginning:]
X = X.iloc[:index_of_test_data_beginning]

X_train, X_test, y_train, y_test = model_selection.train_test_split(
    X,
    y,
    test_size=.15,
    random_state=42
)

# %%
def opt_objective(trial):
    # hyperparameter_max_depth_range = trial.suggest_int(name="max_depth", low=2, high=64, log=True)
    # hyperparameter_n_estimators_range = trial.suggest_int(name="n_estimators", low=30, high=500, log=True)
    # hyperparameter_min_samples_leaf_range = trial.suggest_int(name="min_samples_leaf", low=1, high=3)
    # hyperparameter_criterion_range = trial.suggest_categorical(name="criterion", choices=["gini", "entropy"])
    # hyperparameter_min_samples_split_range = trial.suggest_int(name="min_samples_split", low=2, high=6, log=True)
    # hyperparameter_max_features_range = trial.suggest_categorical(name="max_features", choices=["sqrt", "log2", None])
    # 
    # classifier_tuned_with_random_hyperparameter_values = ensemble.ExtraTreesClassifier(
    #     n_estimators=hyperparameter_n_estimators_range,
    #     criterion=hyperparameter_criterion_range,
    #     max_depth=hyperparameter_max_depth_range,
    #     min_samples_split=hyperparameter_min_samples_split_range,
    #     min_samples_leaf=hyperparameter_min_samples_leaf_range,
    #     max_features=hyperparameter_max_features_range,
    #     warm_start=True,
    #     random_state=42,
    # )
    hidden_layer_sizes_range = trial.suggest_int(name="hidden_layer_sizes", low=50, high=500, log=True)
    solver_range = trial.suggest_categorical(name="solver", choices=["lbfgs", "adam", "sgd"])
    max_iter_range = trial.suggest_int(name="max_iter", low=100, high=500, log=True)
    learning_rate_range = trial.suggest_categorical(name="learning_rate", choices=["constant", "invscaling", "adaptive"])

    classifier_tuned_with_random_hyperparameter_values = neural_network.MLPClassifier(
        hidden_layer_sizes=hidden_layer_sizes_range,
        solver=solver_range,
        max_iter=max_iter_range,
        learning_rate=learning_rate_range,
        warm_start=True
    )
    
    multilabel_classifier_ =multioutput.ClassifierChain(classifier_tuned_with_random_hyperparameter_values)

    multilabel_classifier_.fit(X_train, y_train)
    # classifier_chain.score
    predictions_col_wise_ = multilabel_classifier_.predict(X_test).T
    
    mean_metric_scores = {"f1": 0, "cohen_kappa": 0, "accuracy": 0}
    for i, (predictions, label) in enumerate(zip(predictions_col_wise_, y_test.columns)):
        actual_values = y_test[label]
    
        accuracy_score = metrics.accuracy_score(actual_values, predictions)
        mean_metric_scores["accuracy"] += accuracy_score
    
        f1_score = metrics.f1_score(actual_values, predictions)
        mean_metric_scores["f1"] += f1_score
    
        cohen_kappa_score = metrics.cohen_kappa_score(actual_values, predictions)
        mean_metric_scores["cohen_kappa"] += cohen_kappa_score
    for metric_name in mean_metric_scores.keys():
        mean_metric_scores.update({metric_name: mean_metric_scores.get(metric_name) / 4})
    return tuple(mean_metric_scores.values())

# study = optuna.create_study(directions=["maximize", "maximize", "maximize"])
# 
# study.optimize(opt_objective, n_trials=100)
# 
# trial_with_highest_mean_metric_scores = max(study.best_trials, key=lambda x: x.values[1])
# print(trial_with_highest_mean_metric_scores.params)
# print(trial_with_highest_mean_metric_scores.values)
# Out:
# [I 2024-02-21 11:57:51,682] A new study created in memory with name: no-name-aa32f4ec-2001-4738-ac7b-3a36746d6759
# /home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:698: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# /home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:698: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# /home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:698: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# [I 2024-02-21 11:58:18,151] Trial 0 finished with values: [0.8542365517342058, 0.6255880619511995, 0.8542094455852156] and parameters: {'hidden_layer_sizes': 499, 'solver': 'adam', 'max_iter': 377, 'learning_rate': 'adaptive'}.
# /home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:698: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# /home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (109) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-02-21 11:58:20,429] Trial 1 finished with values: [0.5680830048325929, 0.07324060725759907, 0.6596509240246407] and parameters: {'hidden_layer_sizes': 90, 'solver': 'sgd', 'max_iter': 109, 'learning_rate': 'invscaling'}.
# /home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:698: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# /home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:698: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# /home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (411) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (411) reached and the optimization hasn't converged yet.
#   warnings.warn(
# [I 2024-02-21 11:58:41,382] Trial 2 finished with values: [0.7558684872639321, 0.3435674314483308, 0.784394250513347] and parameters: {'hidden_layer_sizes': 205, 'solver': 'sgd', 'max_iter': 411, 'learning_rate': 'constant'}.
# /home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py:546: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# [W 2024-02-21 11:58:44,565] Trial 3 failed with parameters: {'hidden_layer_sizes': 67, 'solver': 'lbfgs', 'max_iter': 172, 'learning_rate': 'invscaling'} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/optuna/study/_optimize.py", line 200, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_4392/2568653889.py", line 34, in opt_objective
#     multilabel_classifier_.fit(X_train, y_train)
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/multioutput.py", line 926, in fit
#     super().fit(X, Y, **fit_params)
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/multioutput.py", line 723, in fit
#     estimator.fit(
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/base.py", line 1474, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 752, in fit
#     return self._fit(X, y, incremental=False)
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 489, in _fit
#     self._fit_lbfgs(
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 533, in _fit_lbfgs
#     opt_res = scipy.optimize.minimize(
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/scipy/optimize/_minimize.py", line 713, in minimize
#     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/scipy/optimize/_lbfgsb_py.py", line 369, in _minimize_lbfgsb
#     f, g = func_and_grad(x)
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py", line 296, in fun_and_grad
#     self._update_fun()
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py", line 262, in _update_fun
#     self._update_fun_impl()
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py", line 163, in update_fun
#     self.f = fun_wrapped(self.x)
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py", line 145, in fun_wrapped
#     fx = fun(np.copy(x), *args)
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/scipy/optimize/_optimize.py", line 78, in __call__
#     self._compute_if_needed(x, *args)
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/scipy/optimize/_optimize.py", line 72, in _compute_if_needed
#     fg = self.fun(x, *args)
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 282, in _loss_grad_lbfgs
#     loss, coef_grads, intercept_grads = self._backprop(
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 327, in _backprop
#     activations = self._forward_pass(activations)
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/neural_network/_multilayer_perceptron.py", line 174, in _forward_pass
#     activations[i + 1] = safe_sparse_dot(activations[i], self.coefs_[i])
#   File "/home/max/coding/tech_tasks/saber/venv/lib/python3.9/site-packages/sklearn/utils/extmath.py", line 208, in safe_sparse_dot
#     ret = a @ b
# KeyboardInterrupt
# [W 2024-02-21 11:58:44,588] Trial 3 failed with value None.
#
# KeyboardInterrupt

# %%
# # X_ = X.drop(['Просмотр жанра кино в рабочее время',
# #             'Просмотр жанра кино в праздники',
# #             'Просмотр жанра приключения в рабочее время',
# #             'Просмотр жанра приключение в праздники',
# #             'Просмотра жанра сад в рабочее время', 'Просмотр жанра сад в праздники',
# #             'Просмотра жанра комедия в рабочее время',
# #             'Просмотр жанра комедия в праздники',
# #             'Просмотр жанра хоби в рабочее время',
# #             'Просмотр жанра хобби в праздники',
# #             'Просмотр жанра спорт в рабочее время',
# #             'Просмотр жанра спорт в праздники',
# #             'Просмотр жанра музыка в рабочее время',
# #             'Просмотр жанра музыка в праздники',
# #             'Просмотр жанра образования в рабочее время',
# #             'Просмотр жанра образование в праздники'], axis=1)
# 
# # X_final_test = X.iloc[index_of_test_data_beginning:]
# X__ = X.iloc[:index_of_test_data_beginning]
# 
# X_train_, X_test_, y_train_, y_test_ = model_selection.train_test_split(
#     X__,
#     y,
#     test_size=.15,
#     random_state=42
# )
# 
best_found_model = ensemble.ExtraTreesClassifier(
    max_depth=64,
    n_estimators=59,
    min_samples_leaf=1,
    criterion='gini',
    min_samples_split=2,
    max_features='sqrt',
    warm_start=True,
    random_state=42
)
multilabel_classifier =multioutput.ClassifierChain(
    best_found_model,
    random_state=42
)
# 
multilabel_classifier.fit(X_train, y_train)

multilabel_predictions = multilabel_classifier.predict(X_test).T

scores_per_metric = pd.DataFrame(columns=predictor_col_names, index=["accuracy","f1", "cohen_kappa"])
for i, (predictions, predictor_col_name) in enumerate(zip(multilabel_predictions, predictor_col_names)):
    actual_values = y_test[predictor_col_name]

    accuracy_score = metrics.accuracy_score(actual_values, predictions)
    f1_score = metrics.f1_score(actual_values, predictions)
    cohen_kappa_score = metrics.cohen_kappa_score(actual_values, predictions)

    scores_per_metric.loc["accuracy", predictor_col_name] = accuracy_score
    scores_per_metric.loc["f1", predictor_col_name, ] = f1_score
    scores_per_metric.loc["cohen_kappa", predictor_col_name] = cohen_kappa_score

# for metric_name in scores_per_metric.keys():
#     print(f"Mean {metric_name} score: {sum(scores_per_metric.get(metric_name)) / 3}.")
scores_per_metric
# for target_label, accuracy_score in zip(target_labels, scores_per_metric.get("accuracy")):
#     print(f"Accuracy score for label ['{target_label}']: {accuracy_score}")
# classifier_chain.score
# Out:
#              Оператор Есть ли Интернет Члены семьи в возрасте от 55 лет  \
# accuracy     0.958932         0.874743                         0.895277
# f1           0.977477         0.826211                         0.904673
# cohen_kappa  0.746248         0.728844                         0.788573
#
#             Члены семьи до 18 лет
# accuracy                 0.950719
# f1                       0.954545
# cohen_kappa              0.900735

# %%
# best_found_model = ensemble.ExtraTreesClassifier(
#     max_depth=64,
#     n_estimators=59,
#     min_samples_leaf=1,
#     criterion='gini',
#     min_samples_split=2,
#     max_features='sqrt',
#     warm_start=True,
#     random_state=42 
# )
# multilabel_classifier =multioutput.ClassifierChain(
#     best_found_model,
#     random_state=42
# )
# # 
# multilabel_classifier.fit(X_train, y_train.loc[:, ["Оператор", "Есть ли Интернет", "Члены семьи в возрасте от 55 лет"]])
# 
# multilabel_predictions = multilabel_classifier.predict(X_test)
# 
# 
# # multilabel_classifier = multioutput.MultiOutputClassifier(best_found_model)
# # 
# best_found_model.fit(X_train, y_train.loc[:, "Члены семьи до 18 лет"])
# # 
# predictions_col_wise = np.concatenate((multilabel_predictions, best_found_model.predict(X_test).reshape(-1, 1)), axis=1).T
# 
# scores_per_metric = pd.DataFrame(columns=predictor_col_names, index=["accuracy","f1", "cohen_kappa"])
# for i, (predictions, predictor_col_name) in enumerate(zip(predictions_col_wise, predictor_col_names)):
#     actual_values = y_test[predictor_col_name]
# 
#     accuracy_score = metrics.accuracy_score(actual_values, predictions)
#     f1_score = metrics.f1_score(actual_values, predictions)
#     cohen_kappa_score = metrics.cohen_kappa_score(actual_values, predictions)
#     
#     scores_per_metric.loc["accuracy", predictor_col_name] = accuracy_score
#     scores_per_metric.loc["f1", predictor_col_name, ] = f1_score
#     scores_per_metric.loc["cohen_kappa", predictor_col_name] = cohen_kappa_score
# 
# # for metric_name in scores_per_metric.keys():
# #     print(f"Mean {metric_name} score: {sum(scores_per_metric.get(metric_name)) / 3}.")
# scores_per_metric
# # for target_label, accuracy_score in zip(target_labels, scores_per_metric.get("accuracy")):
# #     print(f"Accuracy score for label ['{target_label}']: {accuracy_score}")
# # classifier_chain.score

# %%
final_predictions_col_wise = np.concatenate((multilabel_classifier.predict(X_final_test), best_found_model.predict(X_final_test).reshape(-1, 1)), axis=1).T

final_predictions_per_label = {}
for i, label in enumerate(y_test.columns):
    final_predictions_per_label[label] = final_predictions_col_wise[i].astype(int)

# %%
# final_predictions_per_label = classifier_chain.predict(X_final_test).T

# %%
# predictions_per_label_in_categorical_form =  np.empty(shape=(len(final_predictions_per_label.keys()), len(list(final_predictions_per_label.values())[0])), dtype=object)
# for i, label in enumerate(encoder_per_label.keys()):
#     predictions_per_label_in_categorical_form[i] = encoder_per_label[label].inverse_transform(final_predictions_per_label[label])
# 
# # for i, label in enumerate(predictions_per_label_in_categorical_form.keys()):
# #     predictions_per_row[i] = predictions_per_label_in_categorical_form[label].T
# # predictions_per_row_target_formatted = np.empty(shape=(len(predictions_per_row),len(target_labels)) ) 
# 
# predictions_for_household_structure = list(map(
#     " и ".join,
#     zip(
#         predictions_per_label_in_categorical_form[-2],
#         predictions_per_label_in_categorical_form[-1]
#     )
# ))
# 
# predictions_per_label_in_final_format = np.empty(shape=(len(target_labels), len(predictions_per_label_in_categorical_form[0])), dtype=object)
# for i in range(len(target_labels)-1):
#     predictions_per_label_in_final_format[i] = predictions_per_label_in_categorical_form[i]
# predictions_per_label_in_final_format[2] = predictions_for_household_structure
# 
# predictions_per_row = predictions_per_label_in_final_format.T
# 
# predictions_per_row_in_final_format = pd.DataFrame(predictions_per_row, columns=target_labels)
# predictions_per_row_in_final_format.insert(loc=0, column="id", value=range(1, len(predictions_per_row_in_final_format.index) + 1))
# # for i, predictions in enumerate(predictions_per_row):
# #     predictions_per_row_in_final_format[i] = np.insert(predictions, 0, i+1)
# 
# with open("data/submission.csv", "w+") as submission_file:
#     writer = csv.writer(submission_file)
#     writer.writerow(predictions_per_row_in_final_format.columns)
#     writer.writerows(predictions_per_row_in_final_format.to_numpy())
